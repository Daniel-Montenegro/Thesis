# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
N=1000

#posiciones aleatorias para las particulas

x= np.random.rand(N)
y= np.random.rand(N)
z= np.random.rand(N)

# %%
plt.scatter(x, y)
plt.show()

# %%
##### grafica en 3d
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


ax.scatter(x, y, z,s=1, marker='o')
plt.show()

# %%
#Asignacion de id, velocidad y masa a las particulas. para n=1000

##asignacion de id

##velocidad 
N=500

vx=2*(np.random.rand(N))-1

vy=2*(np.random.rand(N))-1


vz=2*(np.random.rand(N))-1


## masa

m=np.absolute(0.9-(np.random.rand(N)))

############################################
### crear grupos y subgrupos con h5py#######
############################################

try:
    f.close()
except:
    None
f = h5py.File("Snapshot.hdf5", "w") ### se crea el archivo

grp1=f.create_group("Parttype1") ## para crear el subgrupo
grp2=f.create_group("Parttype2") ## para crear el subgrupo

parttype1=grp1.create_dataset('position',(N,3),dtype='f',data=np.transpose([x,y,z]))

parttype1=x
parttype1=y
parttype1=z

parttype1=grp1.create_dataset('mass',(N,1),dtype='f',data=[m])
parttype1=m

parttype1=grp1.create_dataset('velocity',(N,3),dtype='f',data=np.transpose([vx,vy,vz]))
parttype1=vx
parttype1=vy
parttype1=vz

# %%
##########para n=500 particulas

n=500

#posiciones aleatorias para las particulas

x= np.random.rand(n)
y= np.random.rand(n)
z= np.random.rand(n)

##### grafica en 3d
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


ax.scatter(x, y, z,s=1, marker='o')
plt.show()


#Asignacion de id, velocidad y masa a las particulas. 



##velocidad 


vx=2*(np.random.rand(n))-1

vy=2*(np.random.rand(n))-1

vz=2*(np.random.rand(n))-1


## masa

m=np.absolute(0.9-(np.random.rand(n)))

############################################
### crear grupos y subgrupos con h5py#######
############################################


#grp1=f.create_group("Parttype1") ## para crear el subgrupo
#grp2=f.create_group("Parttype2") ## para crear el subgrupo

parttype2=grp2.create_dataset('position',(n,3),dtype='f',data=np.transpose([x,y,z]))

parttype2=x
parttype2=y
parttype2=z

parttype2=grp2.create_dataset('mass',(n,1),dtype='f',data=[m])
parttype2=m

parttype2=grp2.create_dataset('velocity',(n,3),dtype='f',data=np.transpose([vx,vy,vz]))
parttype2=vx
parttype2=vy
parttype2=vz


f.close() ## esto se pone al terminar de editar

# %%
######################################
######################################
####leer archivos a python ###########
######################################


f = h5py.File("Snapshot.hdf5", "r") ### se crea el archivo

# %%
x1,y1,z1=np.array(f['Parttype1/position']).T 
x1,y1,z1=np.array(f['Parttype2/position']).T

# %%
fig = plt.figure(1)
ax = fig.add_subplot(111, projection='3d')


ax.scatter(x1, y1, z1,s=1, marker='o')

ax.scatter(x2, y2, z2,s=1, marker='o')
plt.show()
